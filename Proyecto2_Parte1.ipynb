# %% [markdown]
# <a href="https://colab.research.google.com/github/GPINTOC/Proyecto-2-Coding-Dojo/blob/main/Proyecto2_Parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Para esta tarea:**
#
# Creen un cuaderno de Colab donde hayan subido y mostrado el .head() de cada uno de los conjuntos de datos.  Para cada uno de los conjuntos de datos propuestos, respondan las siguientes preguntas:

# %%
import numpy as np
import pandas as pd

# %%
filename1 = '/content/drive/MyDrive/Documentos CodingDojo/parkinson.csv'
df1 = pd.read_csv(filename1)
df1
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %% [markdown]
# Primera opción: conjunto de datos 1
#
# **1) Fuente de datos**
# - https://www.kaggle.com/datasets/debasisdotcom/parkinson-disease-detection
#
# **2) Breve descripción de datos**
# - Parkinson es una enfermedad neurodegenerativa que se manifiesta a través de un deterioro del movimiento, incluyendo la presencia de temblores y rigidez. Por lo general, hay un efecto marcado en el habla, que incluye disartria (dificultad para articular sonidos), hipofonía (volumen más bajo) y monotonía (gama de tono reducida).
#
# **3) ¿Cuál es el objetivo?**
# - El objetivo es contar con un proceso de detección eficaz de Parkinson, que no requiera una visita a la clínica, a través de diferentes categorías de tonos y características de voz
#
# **4) ¿Este es un problema de clasificación o regresión?**
# - Clasificación, el status de enfermedad 0-1, saludable o parkinson.
#
# **5) ¿Cuántas características hay?**
# - 24 características
#
# **6) ¿Cuántas filas de datos hay?**
# - 195 filas
#
# **7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?**
# - A simple vista no detecto valores nulos ni aberrantes, sin embargo veo valores negativos que podrían ocasionar algún tipo de inconveniente

# %%
filename2 = '/content/drive/MyDrive/Documentos CodingDojo/cancer de mamas.csv'
df2 = pd.read_csv(filename2)
df2
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 334 non-null    int64
#  1   Gender              334 non-null    object
#  2   Protein1            334 non-null    float64
#  3   Protein2            334 non-null    float64
#  4   Protein3            334 non-null    float64
#  5   Protein4            334 non-null    float64
#  6   Tumour_Stage        334 non-null    object
#  7   Histology           334 non-null    object
#  8   ER status           334 non-null    object
#  9   PR status           334 non-null    object
#  10  HER2 status         334 non-null    object
#  11  Surgery_type        334 non-null    object
#  12  Date_of_Surgery     334 non-null    object
#  13  Date_of_Last_Visit  317 non-null    object
#  14  Patient_Status      321 non-null    object
# ...

# %% [markdown]
# Segunda opción: conjunto de datos 2
#
# **1) Fuente de datos**
#
# https://www.kaggle.com/datasets/kreeshrajani/breast-cancer-survival-dataset
#
# **2) Breve descripción de datos**
#
# El cáncer de mama es una enfermedad común que se desarrolla por la división rápida de células malignas y provoca que se expanda a otros órganos si no es tratado a tiempo. El dataset contiene información sobre pacientes incluido su ID, edad, sexo y niveles de expresión de cuatro proteínas (Proteína 1, Proteína 2, Proteína 3, Proteína 4). Además incluye el estadio del cáncer de mama del paciente (Tumor_Stage), Histología (tipo de cáncer), estado de ER, PR y HER2, tipo de cirugía, fecha de la cirugía, fecha de la última visita y estado del paciente (vivo/muerto).
#
# **3) ¿Cuál es el objetivo?**
#
# Análisis de la relación entre los niveles de expresión de proteínas, el estadio del cáncer y los resultados de los pacientes. También se puede utilizar para comprender el impacto de los diferentes tipos de cirugías en la supervivencia del paciente y para identificar los factores de riesgo potenciales para la progresión del cáncer de mama.
#
# **4) ¿Este es un problema de clasificación o regresión?**
#
# Clasificación
#
# **5) ¿Cuántas características hay?**
#
# 15 columnas
#
# **6) ¿Cuántas filas de datos hay?**
#
# 334 filas
#
# **7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?**
#
# Hay datos nulos o desconocidos que habría que imputar, hay fechas descritas como objetos que deberían ser transformadas si es que la columna fuera relevante, habría que realizar one hot encoder a las columnas de clases no ordenadas descritas como objetos y debería definir yo el objetivo del problema, ya que solo es una base de datos con información para ser analizada.
